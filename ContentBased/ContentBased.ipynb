# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credits = pd.read_csv('dataset/tmdb_5000_credits.csv')
movies_df = pd.read_csv('dataset/tmdb_5000_movies.csv')
print("Credits:",credits.shape)
print("Movies Dataframe:",movies_df.shape)
# Out:
# Credits: (4803, 4)
# Movies Dataframe: (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits = credits.rename(index=str, columns={"movie_id": "id"})
movies = movies_df.merge(credits, on='id')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
movies.drop(['production_companies','title_x','title_y','status'],axis=1,inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_countries  4803 non-null   object
#  10  release_date          4802 non-null   object
#  11  revenue               4803 non-null   int64
#  12  runtime               4801 non-null   float64
#  13  spoken_languages      4803 non-null   object
#  14  tagline               3959 non-null   object
# ...

# %%
import ast
features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    movies[feature] = movies[feature].map(lambda x: ast.literal_eval(x))

def make_genresList(x):
    if isinstance(x, list):
        for i in x:
            if i['name'] == 'Science Fiction':
                i['name'] = 'Sci-Fi'
        names = [i['name'] for i in x]
        return names
    return []
movies['genres'] = movies['genres'].map(lambda x: make_genresList(x))

def make_directorList(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan
movies['director'] = movies['crew'].map(lambda x: make_directorList(x))

def make_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 3:
            names = names[:3]
        return names
    return []

features = ['cast', 'keywords']
for feature in features:
    movies[feature] = movies[feature].map(lambda x: make_list(x))

# %%
movies.head()
# Out:
#       budget                                genres  \
# 0  237000000  [Action, Adventure, Fantasy, Sci-Fi]
# 1  300000000          [Adventure, Fantasy, Action]
# 2  245000000            [Action, Adventure, Crime]
# 3  250000000      [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Sci-Fi]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                 keywords original_language  \
# 0     [culture clash, future, space war]                en
# 1     [ocean, drug abuse, exotic island]                en
# 2    [spy, based on novel, secret agent]                en
# 3  [dc comics, crime fighter, terrorist]                en
# ...

# %% [markdown]
# ### Weighted Average Rating Based Recommendation System

# %%
movies0 = movies.copy()

# %%
movies0.shape
# Out:
# (4803, 20)

# %%
v=movies0['vote_count']
R=movies0['vote_average']
C=movies0['vote_average'].mean()
C
# Out:
# 6.092171559442016

# %%
m=movies0['vote_count'].quantile(0.70)
m
# Out:
# 581.0

# %%
movies0['weighted_average']=((R*v)+ (C*m))/(v+m)

# %%
movies0.head()
# Out:
#       budget                                genres  \
# 0  237000000  [Action, Adventure, Fantasy, Sci-Fi]
# 1  300000000          [Adventure, Fantasy, Action]
# 2  245000000            [Action, Adventure, Crime]
# 3  250000000      [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Sci-Fi]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                 keywords original_language  \
# 0     [culture clash, future, space war]                en
# 1     [ocean, drug abuse, exotic island]                en
# 2    [spy, based on novel, secret agent]                en
# 3  [dc comics, crime fighter, terrorist]                en
# ...

# %%
movies0.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'tagline',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director',
#        'weighted_average'],
#       dtype='object')

# %%
movies0[['original_title','vote_average','vote_count','weighted_average','popularity']].sort_values(
    'weighted_average',ascending=False).head(10)
# Out:
#                 original_title  vote_average  vote_count  weighted_average  \
# 1881  The Shawshank Redemption           8.5        8205          8.340775
# 3337             The Godfather           8.4        5893          8.192887
# 662                 Fight Club           8.3        9413          8.171648
# 3232              Pulp Fiction           8.3        8428          8.157615
# 65             The Dark Knight           8.2       12002          8.102674
# 809               Forrest Gump           8.2        7927          8.056059
# 1818          Schindler's List           8.3        4329          8.038748
# 3865                  Whiplash           8.3        4254          8.034695
# 96                   Inception           8.1       13752          8.018611
# 1990   The Empire Strikes Back           8.2        5879          8.010426
#
#       popularity
# 1881  136.747729
# 3337  143.659698
# 662   146.757391
# 3232  121.463076
# 65    187.322927
# 809   138.133331
# ...

# %%
weighted_average= movies0.sort_values('weighted_average', ascending=False)
plt.figure(figsize=(12,4))
plt.barh(weighted_average['original_title'].head(6),weighted_average['weighted_average'].head(6), align='center',color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.title('Best Movies by average votes', weight='bold')
# Out:
# Text(0.5, 1.0, 'Best Movies by average votes')

# %%
popularity= movies0.sort_values('popularity', ascending=False)
plt.figure(figsize=(12,4))
plt.barh(popularity['original_title'].head(6),popularity['popularity'].head(6), align='center',color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel("Popularity",weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.title("Popular Movies",weight='bold')
# Out:
# Text(0.5, 1.0, 'Popular Movies')

# %% [markdown]
# ### Overview(Plot) Based Recommendation System

# %%
movies1 = movies.copy()

# %%
movies1['overview'].head(2)
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tvf = TfidfVectorizer(min_df=3, max_features=None,strip_accents='unicode',analyzer='word',token_pattern=r'\w{1,}',
                      ngram_range=(1,3),stop_words= 'english')
movies1['overview'] = movies1['overview'].fillna('')

# %%
tvf_matrix = tvf.fit_transform(movies1['overview'])

# %%
tvf_matrix.shape
# Out:
# (4803, 10417)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

sig = sigmoid_kernel(tvf_matrix,tvf_matrix)

# %%
sig[0]
# Out:
# array([0.76163447, 0.76159416, 0.76159416, ..., 0.76159416, 0.76159416,
#        0.76159416])

# %%
indices = pd.Series(movies1.index, index = movies1['original_title']).drop_duplicates()

# %%
indices.head(15)
# Out:
# original_title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
# Spider-Man 3                                   5
# Tangled                                        6
# Avengers: Age of Ultron                        7
# Harry Potter and the Half-Blood Prince         8
# Batman v Superman: Dawn of Justice             9
# Superman Returns                              10
# Quantum of Solace                             11
# Pirates of the Caribbean: Dead Man's Chest    12
# The Lone Ranger                               13
# Man of Steel                                  14
# dtype: int64

# %%
def recommendation1(title,sig=sig):
    idx = indices[title]
    sig_scores = list(enumerate(sig[idx]))
    sig_scores = sorted(sig_scores, key=lambda x:x[1], reverse=True)
    sig_scores = sig_scores[1:11]
    movie_indices = [i[0] for i in sig_scores]
    data =  {
                'title':[movies1['original_title'].iloc[i] for i in movie_indices],
                'score':[sig_scores[j][1] for j in range(0,len(sig_scores))],
                'genres':[movies1['genres'].iloc[i] for i in movie_indices],
                'keywords':[movies1['keywords'].iloc[i] for i in movie_indices]
            }
    df = pd.DataFrame(data)
    return df

# %%
recommendation1('Avatar')
# Out:
#                           title     score  \
# 0              Obitaemyy Ostrov  0.761603
# 1                    The Matrix  0.761602
# 2                     Apollo 18  0.761601
# 3                  The American  0.761601
# 4                     Supernova  0.761601
# 5              Tears of the Sun  0.761599
# 6                       Beowulf  0.761599
# 7  The Adventures of Pluto Nash  0.761599
# 8                      Semi-Pro  0.761599
# 9              The Book of Life  0.761598
#
#                                               genres  \
# 0                [Action, Fantasy, Sci-Fi, Thriller]
# 1                                   [Action, Sci-Fi]
# 2                         [Horror, Thriller, Sci-Fi]
# 3                           [Crime, Drama, Thriller]
# 4                         [Horror, Sci-Fi, Thriller]
# 5                               [Action, Drama, War]
# 6                     [Adventure, Action, Animation]
# 7                           [Action, Comedy, Sci-Fi]
# ...

# %%
recommendation1('Avengers: Age of Ultron')
# Out:
#                         title     score  \
# 0                    Iron Man  0.761602
# 1                  Iron Man 2  0.761602
# 2                  Iron Man 3  0.761601
# 3                    The Core  0.761599
# 4                       Heist  0.761599
# 5              Knight and Day  0.761599
# 6                  Gettysburg  0.761599
# 7     Space Battleship Yamato  0.761599
# 8                 Unstoppable  0.761598
# 9  Back to the Future Part II  0.761598
#
#                                   genres  \
# 0            [Action, Sci-Fi, Adventure]
# 1            [Adventure, Action, Sci-Fi]
# 2            [Action, Adventure, Sci-Fi]
# 3  [Action, Thriller, Adventure, Sci-Fi]
# 4              [Crime, Action, Thriller]
# 5                       [Action, Comedy]
# 6                  [War, Drama, History]
# 7                               [Sci-Fi]
# 8                     [Action, Thriller]
# 9    [Adventure, Comedy, Family, Sci-Fi]
#
#                                             keywords
# ...

# %% [markdown]
# ### Genres,Keywords,Cast and Crew Based Recommendation System

# %%
movies[['original_title', 'cast', 'director', 'keywords', 'genres']].head()
# Out:
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                cast           director  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      James Cameron
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     Gore Verbinski
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         Sam Mendes
# 3      [Christian Bale, Michael Caine, Gary Oldman]  Christopher Nolan
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     Andrew Stanton
#
#                                 keywords                                genres
# 0     [culture clash, future, space war]  [Action, Adventure, Fantasy, Sci-Fi]
# 1     [ocean, drug abuse, exotic island]          [Adventure, Fantasy, Action]
# ...

# %%
movies2 = movies.copy()

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''
        
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    movies2[feature] = movies2[feature].apply(clean_data)

# %%
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
movies2['soup'] = movies2.apply(create_soup, axis=1)

# %%
movies2['soup'].head()
# Out:
# 0    cultureclash future spacewar samworthington zo...
# 1    ocean drugabuse exoticisland johnnydepp orland...
# 2    spy basedonnovel secretagent danielcraig chris...
# 3    dccomics crimefighter terrorist christianbale ...
# 4    basedonnovel mars medallion taylorkitsch lynnc...
# Name: soup, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movies2['soup'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
movies2 = movies2.reset_index()
indices = pd.Series(movies2.index, index=movies2['original_title'])

# %%
movies2.head(2)
# Out:
#    index     budget                                genres  \
# 0      0  237000000  [action, adventure, fantasy, sci-fi]
# 1      1  300000000          [adventure, fantasy, action]
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                            keywords original_language  \
# 0  [cultureclash, future, spacewar]                en
# 1  [ocean, drugabuse, exoticisland]                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
#
#       revenue runtime                                   spoken_languages  \
# ...

# %%
def recommendation2(title,cosine_sim=cosine_sim):
    idx = indices[title]
    cos_scores = list(enumerate(cosine_sim[idx]))
    cos_scores = sorted(cos_scores, key=lambda x:x[1], reverse=True)
    cos_scores = cos_scores[1:11]
    movie_indices = [i[0] for i in cos_scores]
    data =  {
                'title':[movies['original_title'].iloc[i] for i in movie_indices],
                'score':[cos_scores[j][1] for j in range(0,len(cos_scores))],
                'genres':[movies['genres'].iloc[i] for i in movie_indices],
                'keywords':[movies['keywords'].iloc[i] for i in movie_indices],
                'cast':[movies['cast'].iloc[i] for i in movie_indices],
                'director':[movies['director'].iloc[i] for i in movie_indices]
            }
    df = pd.DataFrame(data)
    return df

# %%
recommendation2('Avengers: Age of Ultron')
# Out:
#                              title     score  \
# 0                     The Avengers  0.727273
# 1                       Iron Man 2  0.636364
# 2       Captain America: Civil War  0.545455
# 3                          Ant-Man  0.545455
# 4                            X-Men  0.545455
# 5                               X2  0.522233
# 6             Thor: The Dark World  0.476731
# 7                       Iron Man 3  0.454545
# 8  Transformers: Age of Extinction  0.454545
# 9          Star Trek Into Darkness  0.454545
#
#                                   genres  \
# 0            [Sci-Fi, Action, Adventure]
# 1            [Adventure, Action, Sci-Fi]
# 2            [Adventure, Action, Sci-Fi]
# 3            [Sci-Fi, Action, Adventure]
# 4            [Adventure, Action, Sci-Fi]
# 5  [Adventure, Action, Sci-Fi, Thriller]
# 6           [Action, Adventure, Fantasy]
# 7            [Action, Adventure, Sci-Fi]
# 8            [Sci-Fi, Action, Adventure]
# 9            [Action, Adventure, Sci-Fi]
#
# ...

# %%
recommendation2('Superman Returns')
# Out:
#                               title     score  \
# 0                      Man of Steel  0.583333
# 1                          Superman  0.583333
# 2                       Superman II  0.583333
# 3                      Superman III  0.560449
# 4        X-Men: Days of Future Past  0.500000
# 5  Superman IV: The Quest for Peace  0.500000
# 6                     Suicide Squad  0.480384
# 7                            Sheena  0.447214
# 8                             X-Men  0.435194
# 9               The Helix... Loaded  0.433013
#
#                                          genres  \
# 0          [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy, Sci-Fi]
# 2          [Action, Adventure, Fantasy, Sci-Fi]
# 3  [Comedy, Action, Adventure, Fantasy, Sci-Fi]
# 4          [Action, Adventure, Fantasy, Sci-Fi]
# 5                   [Action, Adventure, Sci-Fi]
# 6   [Action, Adventure, Crime, Fantasy, Sci-Fi]
# 7  [Action, Adventure, Comedy, Fantasy, Sci-Fi]
# ...
